# %% [markdown]
# ## Plot_things
#
# For plotting data from the three phases together

# %%
#imports
import math
import numpy as np
import pandas as pd
import os
import sys
import subprocess
import matplotlib as plt
import seaborn as sns
# %matplotlib qt

# %%
#dataframes to load
trunc_xls=['phase1_waterfall_trun.xlsx','phase2_waterfall_trun.xlsx','phase2_waterfall_trun.xlsx']
full_xls=['phase1_waterfall_full.xlsx','phase2_waterfall_full.xlsx','phase3_waterfall_full.xlsx']
    

trunc_dfs={}
for xls in trunc_xls:
    trunc_dfs[xls]=pd.read_excel(xls)

# %%
#load in csvs instead of excel files
#excel writer doesnt write full dataframe because reasons

phase1full=pd.read_csv('phase1_waterfall_full.csv')
phase2full=pd.read_csv('phase2_waterfall_full.csv')
phase3full=pd.read_csv('phase3_waterfall_full.csv')

phase1full = phase1full.drop('Unnamed: 0',axis=1)
phase2full = phase2full.drop('Unnamed: 0',axis=1)
phase3full = phase3full.drop('Unnamed: 0',axis=1)

#shift phase datapoints by positive 0.8 * 0.015625 so they match up with phase1 and phase2 datapoints
#this is very bad but otherwise the combined dataframe columns become unfixably unsorted somehow
#phase3full.columns=np.arange(949.2+(0.8*0.015625),1439.2+(0.8*0.015625),0.015625)

# %%
full_dfs={}
full_dfs['phase1full']=phase1full
full_dfs['phase2full']=phase2full
#full_dfs['phase3full']=phase3full

#all_phases=pd.concat(full_dfs,axis=0)
#all_phases.index=range(0,83)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-413459d5a9ae> in <module>()
#       6 all_phases=pd.concat(full_dfs,axis=0)
#       7 #all_phases.sort(axis=1,inplace=True)
# ----> 8 all_phases.index=range(0,83)
#
# /Users/evansmith/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    2683         try:
#    2684             object.__getattribute__(self, name)
# -> 2685             return object.__setattr__(self, name, value)
#    2686         except AttributeError:
#    2687             pass
#
# pandas/src/properties.pyx in pandas.lib.AxisProperty.__set__ (pandas/lib.c:44748)()
#
# /Users/evansmith/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     426
#     427     def _set_axis(self, axis, labels):
# --> 428         self._data.set_axis(axis, labels)
#     429         self._clear_item_cache()
#     430
#
# /Users/evansmith/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    2633             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2634                              'new values have %d elements' %
# -> 2635                              (old_len, new_len))
#    2636
#    2637         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 74 elements, new values have 83 elements

# %%
all_phases
# Out:
#       1000.0  1000.00625  1000.0125  1000.015625  1000.021875  1000.028125  \
# 0   0.270041         NaN        NaN     0.269834          NaN          NaN
# 1   0.222620         NaN        NaN     0.222584          NaN          NaN
# 2   0.245753         NaN        NaN     0.244961          NaN          NaN
# 3   0.355457         NaN        NaN     0.295139          NaN          NaN
# 4   0.356927         NaN        NaN     0.319328          NaN          NaN
# 5   0.469603         NaN        NaN     0.442908          NaN          NaN
# 6   0.397483         NaN        NaN     0.364279          NaN          NaN
# 7   0.383105         NaN        NaN     0.347790          NaN          NaN
# 8   0.296131         NaN        NaN     0.243593          NaN          NaN
# 9   0.311494         NaN        NaN     0.260249          NaN          NaN
# 10  0.349204         NaN        NaN     0.322675          NaN          NaN
# 11  0.331455         NaN        NaN     0.299089          NaN          NaN
# 12  0.603086         NaN        NaN     0.577078          NaN          NaN
# 13  0.370800         NaN        NaN     0.370466          NaN          NaN
# 14  0.364327         NaN        NaN     0.364724          NaN          NaN
# 15  0.297687         NaN        NaN     0.294874          NaN          NaN
# 16  0.288533         NaN        NaN     0.273120          NaN          NaN
# 17  0.464509         NaN        NaN     0.452744          NaN          NaN
# 18  0.344541         NaN        NaN     0.332670          NaN          NaN
# 19  0.357974         NaN        NaN     0.357469          NaN          NaN
# 20  0.340505         NaN        NaN     0.340242          NaN          NaN
# 21  0.318028         NaN        NaN     0.317310          NaN          NaN
# 22  0.280076         NaN        NaN     0.280026          NaN          NaN
# 23  0.305880         NaN        NaN     0.305874          NaN          NaN
# 24  0.286203         NaN        NaN     0.246923          NaN          NaN
# 25  0.214784         NaN        NaN     0.201362          NaN          NaN
# 26  0.243523         NaN        NaN     0.243432          NaN          NaN
# 27  0.372093         NaN        NaN     0.307002          NaN          NaN
# 28  0.371869         NaN        NaN     0.309318          NaN          NaN
# 29  0.287557         NaN        NaN     0.273586          NaN          NaN
# ..       ...         ...        ...          ...          ...          ...
# 53       NaN    0.487977        NaN          NaN     0.483925          NaN
# 54       NaN    0.455360        NaN          NaN     0.448456          NaN
# 55       NaN    0.527109        NaN          NaN     0.525424          NaN
# 56       NaN    1.000000        NaN          NaN     1.000000          NaN
# 57       NaN    0.737232        NaN          NaN     0.736307          NaN
# 58       NaN    0.236647        NaN          NaN     0.232815          NaN
# 59       NaN    1.000000        NaN          NaN     1.000000          NaN
# 60       NaN    1.000000        NaN          NaN     1.000000          NaN
# 61       NaN    1.000000        NaN          NaN     1.000000          NaN
# 62       NaN    1.000000        NaN          NaN     1.000000          NaN
# 63       NaN    1.000000        NaN          NaN     1.000000          NaN
# 64       NaN    0.405775        NaN          NaN     0.398536          NaN
# 65       NaN    0.572977        NaN          NaN     0.571514          NaN
# 66       NaN    0.508046        NaN          NaN     0.506805          NaN
# 67       NaN    0.525876        NaN          NaN     0.525325          NaN
# 68       NaN    0.435886        NaN          NaN     0.434408          NaN
# 69       NaN    0.462764        NaN          NaN     0.461914          NaN
# 70       NaN    0.410376        NaN          NaN     0.408572          NaN
# 71       NaN    0.396847        NaN          NaN     0.396521          NaN
# 72       NaN    0.307814        NaN          NaN     0.306872          NaN
# 73       NaN    0.557065        NaN          NaN     0.554798          NaN
# 74       NaN         NaN   0.222721          NaN          NaN     0.214845
# 75       NaN         NaN   0.331043          NaN          NaN     0.327798
# 76       NaN         NaN   0.259437          NaN          NaN     0.256494
# 77       NaN         NaN   0.306113          NaN          NaN     0.301754
# 78       NaN         NaN   0.373693          NaN          NaN     0.367947
# 79       NaN         NaN   0.274908          NaN          NaN     0.272532
# 80       NaN         NaN   0.310226          NaN          NaN     0.300174
# 81       NaN         NaN   0.477281          NaN          NaN     0.474558
# 82       NaN         NaN   0.476500          NaN          NaN     0.465379
#
#     1000.03125  1000.0375  1000.04375  1000.046875     ...        999.95  \
# 0     0.269657        NaN         NaN     0.269668     ...           NaN
# 1     0.222539        NaN         NaN     0.222678     ...           NaN
# 2     0.244459        NaN         NaN     0.244382     ...           NaN
# 3     0.283479        NaN         NaN     0.282112     ...           NaN
# 4     0.273231        NaN         NaN     0.261854     ...           NaN
# 5     0.380753        NaN         NaN     0.367090     ...           NaN
# 6     0.315512        NaN         NaN     0.305013     ...           NaN
# 7     0.284571        NaN         NaN     0.269414     ...           NaN
# 8     0.231645        NaN         NaN     0.231375     ...           NaN
# 9     0.249042        NaN         NaN     0.249119     ...           NaN
# 10    0.263975        NaN         NaN     0.252794     ...           NaN
# 11    0.242757        NaN         NaN     0.230730     ...           NaN
# 12    0.553789        NaN         NaN     0.544538     ...           NaN
# 13    0.370923        NaN         NaN     0.370886     ...           NaN
# 14    0.364572        NaN         NaN     0.364218     ...           NaN
# 15    0.294795        NaN         NaN     0.294826     ...           NaN
# 16    0.273044        NaN         NaN     0.273002     ...           NaN
# 17    0.452740        NaN         NaN     0.452769     ...           NaN
# 18    0.333214        NaN         NaN     0.332866     ...           NaN
# 19    0.357010        NaN         NaN     0.356728     ...           NaN
# 20    0.340256        NaN         NaN     0.340314     ...           NaN
# 21    0.317402        NaN         NaN     0.317615     ...           NaN
# 22    0.279970        NaN         NaN     0.279942     ...           NaN
# 23    0.305838        NaN         NaN     0.305775     ...           NaN
# 24    0.230321        NaN         NaN     0.230092     ...           NaN
# 25    0.201253        NaN         NaN     0.201179     ...           NaN
# 26    0.243456        NaN         NaN     0.243504     ...           NaN
# 27    0.298339        NaN         NaN     0.298259     ...           NaN
# 28    0.289003        NaN         NaN     0.288826     ...           NaN
# 29    0.273633        NaN         NaN     0.273658     ...           NaN
# ..         ...        ...         ...          ...     ...           ...
# 53         NaN   0.443551         NaN          NaN     ...           NaN
# 54         NaN   0.395449         NaN          NaN     ...           NaN
# 55         NaN   0.480089         NaN          NaN     ...           NaN
# 56         NaN   1.000000         NaN          NaN     ...           NaN
# 57         NaN   0.714757         NaN          NaN     ...           NaN
# 58         NaN   0.171930         NaN          NaN     ...           NaN
# 59         NaN   1.000000         NaN          NaN     ...           NaN
# 60         NaN   1.000000         NaN          NaN     ...           NaN
# 61         NaN   1.000000         NaN          NaN     ...           NaN
# 62         NaN   1.000000         NaN          NaN     ...           NaN
# 63         NaN   1.000000         NaN          NaN     ...           NaN
# 64         NaN   0.353813         NaN          NaN     ...           NaN
# 65         NaN   0.531906         NaN          NaN     ...           NaN
# 66         NaN   0.477450         NaN          NaN     ...           NaN
# 67         NaN   0.523606         NaN          NaN     ...           NaN
# 68         NaN   0.393126         NaN          NaN     ...           NaN
# 69         NaN   0.453384         NaN          NaN     ...           NaN
# 70         NaN   0.404072         NaN          NaN     ...           NaN
# 71         NaN   0.343687         NaN          NaN     ...           NaN
# 72         NaN   0.255139         NaN          NaN     ...           NaN
# 73         NaN   0.549065         NaN          NaN     ...           NaN
# 74         NaN        NaN    0.206571          NaN     ...      0.199968
# 75         NaN        NaN    0.325002          NaN     ...      0.321220
# 76         NaN        NaN    0.252293          NaN     ...      0.247830
# 77         NaN        NaN    0.297255          NaN     ...      0.293827
# 78         NaN        NaN    0.363059          NaN     ...      0.359213
# 79         NaN        NaN    0.270318          NaN     ...      0.268715
# 80         NaN        NaN    0.289360          NaN     ...      0.282735
# 81         NaN        NaN    0.473899          NaN     ...      0.471071
# 82         NaN        NaN    0.446997          NaN     ...      0.422421
#
#     999.953125  999.959375  999.965625  999.96875   999.975  999.98125  \
# 0     0.378653         NaN         NaN   0.340427       NaN        NaN
# 1     0.325062         NaN         NaN   0.308324       NaN        NaN
# 2     0.365522         NaN         NaN   0.337442       NaN        NaN
# 3     0.371707         NaN         NaN   0.377407       NaN        NaN
# 4     0.338900         NaN         NaN   0.349994       NaN        NaN
# 5     0.444741         NaN         NaN   0.462033       NaN        NaN
# 6     0.379615         NaN         NaN   0.391207       NaN        NaN
# 7     0.353266         NaN         NaN   0.374214       NaN        NaN
# 8     0.319809         NaN         NaN   0.326839       NaN        NaN
# 9     0.339409         NaN         NaN   0.347536       NaN        NaN
# 10    0.329942         NaN         NaN   0.342915       NaN        NaN
# 11    0.310269         NaN         NaN   0.323987       NaN        NaN
# 12    0.591275         NaN         NaN   0.598785       NaN        NaN
# 13    0.476393         NaN         NaN   0.434085       NaN        NaN
# 14    0.470586         NaN         NaN   0.432013       NaN        NaN
# 15    0.401620         NaN         NaN   0.374731       NaN        NaN
# 16    0.380984         NaN         NaN   0.380835       NaN        NaN
# 17    0.535494         NaN         NaN   0.535326       NaN        NaN
# 18    0.475643         NaN         NaN   0.469695       NaN        NaN
# 19    0.442741         NaN         NaN   0.401873       NaN        NaN
# 20    0.446384         NaN         NaN   0.397294       NaN        NaN
# 21    0.434022         NaN         NaN   0.390542       NaN        NaN
# 22    0.392616         NaN         NaN   0.342196       NaN        NaN
# 23    0.399553         NaN         NaN   0.353500       NaN        NaN
# 24    0.327688         NaN         NaN   0.332995       NaN        NaN
# 25    0.322956         NaN         NaN   0.302932       NaN        NaN
# 26    0.332841         NaN         NaN   0.291822       NaN        NaN
# 27    0.386000         NaN         NaN   0.392551       NaN        NaN
# 28    0.385252         NaN         NaN   0.390182       NaN        NaN
# 29    0.369704         NaN         NaN   0.369032       NaN        NaN
# ..         ...         ...         ...        ...       ...        ...
# 53         NaN    0.479325         NaN        NaN  0.482447        NaN
# 54         NaN    0.436426         NaN        NaN  0.443178        NaN
# 55         NaN    0.517085         NaN        NaN  0.520796        NaN
# 56         NaN    1.000000         NaN        NaN  1.000000        NaN
# 57         NaN    0.735825         NaN        NaN  0.737592        NaN
# 58         NaN    0.217424         NaN        NaN  0.225810        NaN
# 59         NaN    1.000000         NaN        NaN  1.000000        NaN
# 60         NaN    1.000000         NaN        NaN  1.000000        NaN
# 61         NaN    1.000000         NaN        NaN  1.000000        NaN
# 62         NaN    1.000000         NaN        NaN  1.000000        NaN
# 63         NaN    1.000000         NaN        NaN  1.000000        NaN
# 64         NaN    0.390005         NaN        NaN  0.402456        NaN
# 65         NaN    0.570275         NaN        NaN  0.572653        NaN
# 66         NaN    0.495978         NaN        NaN  0.501735        NaN
# 67         NaN    0.522485         NaN        NaN  0.526087        NaN
# 68         NaN    0.421501         NaN        NaN  0.427536        NaN
# 69         NaN    0.443133         NaN        NaN  0.449916        NaN
# 70         NaN    0.396663         NaN        NaN  0.400776        NaN
# 71         NaN    0.389177         NaN        NaN  0.397941        NaN
# 72         NaN    0.301163         NaN        NaN  0.307360        NaN
# 73         NaN    0.541335         NaN        NaN  0.546008        NaN
# 74         NaN         NaN    0.203057        NaN       NaN   0.211650
# 75         NaN         NaN    0.325914        NaN       NaN   0.327412
# 76         NaN         NaN    0.249601        NaN       NaN   0.253256
# 77         NaN         NaN    0.296223        NaN       NaN   0.302468
# 78         NaN         NaN    0.365112        NaN       NaN   0.368218
# 79         NaN         NaN    0.268333        NaN       NaN   0.273017
# 80         NaN         NaN    0.283470        NaN       NaN   0.296250
# 81         NaN         NaN    0.475213        NaN       NaN   0.475789
# 82         NaN         NaN    0.429208        NaN       NaN   0.449131
#
#     999.984375  999.990625  999.996875
# 0     0.287917         NaN         NaN
# 1     0.234825         NaN         NaN
# 2     0.266687         NaN         NaN
# 3     0.376589         NaN         NaN
# 4     0.357065         NaN         NaN
# 5     0.469950         NaN         NaN
# 6     0.397862         NaN         NaN
# 7     0.383735         NaN         NaN
# 8     0.326679         NaN         NaN
# 9     0.347061         NaN         NaN
# 10    0.349762         NaN         NaN
# 11    0.331730         NaN         NaN
# 12    0.603182         NaN         NaN
# 13    0.387905         NaN         NaN
# 14    0.380300         NaN         NaN
# 15    0.318543         NaN         NaN
# 16    0.337689         NaN         NaN
# 17    0.511014         NaN         NaN
# 18    0.408463         NaN         NaN
# 19    0.368124         NaN         NaN
# 20    0.358893         NaN         NaN
# 21    0.339546         NaN         NaN
# 22    0.299080         NaN         NaN
# 23    0.318307         NaN         NaN
# 24    0.332630         NaN         NaN
# 25    0.250785         NaN         NaN
# 26    0.253441         NaN         NaN
# 27    0.392164         NaN         NaN
# 28    0.389559         NaN         NaN
# 29    0.336220         NaN         NaN
# ..         ...         ...         ...
# 53         NaN    0.486746         NaN
# 54         NaN    0.452019         NaN
# 55         NaN    0.527279         NaN
# 56         NaN    1.000000         NaN
# 57         NaN    0.738107         NaN
# 58         NaN    0.235324         NaN
# 59         NaN    1.000000         NaN
# 60         NaN    1.000000         NaN
# 61         NaN    1.000000         NaN
# 62         NaN    1.000000         NaN
# 63         NaN    1.000000         NaN
# 64         NaN    0.406389         NaN
# 65         NaN    0.575213         NaN
# 66         NaN    0.508046         NaN
# 67         NaN    0.528109         NaN
# 68         NaN    0.435342         NaN
# 69         NaN    0.462325         NaN
# 70         NaN    0.408030         NaN
# 71         NaN    0.398575         NaN
# 72         NaN    0.311571         NaN
# 73         NaN    0.557180         NaN
# 74         NaN         NaN    0.218135
# 75         NaN         NaN    0.330734
# 76         NaN         NaN    0.258429
# 77         NaN         NaN    0.303858
# 78         NaN         NaN    0.371114
# 79         NaN         NaN    0.274171
# 80         NaN         NaN    0.305547
# 81         NaN         NaN    0.475578
# 82         NaN         NaN    0.468336
#
# [83 rows x 93184 columns]

# %%
#plot waterfall phase 1 csv
sns.heatmap(phase1full)

# %%
#plot waterfall phase 2 csv
sns.heatmap(phase2full)

# %%
#plot waterfall phase 3 csv
sns.heatmap(phase3full)

# %%
sns.heatmap(all_phases,xticklabels=6656)

# %%
#plot cumulative averages of each phase on same plot
ave_dfs={}
for df in full_dfs:
    ave_dfs[df] = full_dfs[df].mean(axis=0)
    
yaxis=np.arange(0,1,0.1)
xaxis=np.arange(944,1439,(1439-944)/25)

nplt=0
for df in ave_dfs.keys():
    if nplt==1:
        ave_dfs[df].plot(ax=ax,grid=True,yticks=yaxis,label=str(df),legend=True)
    if nplt==0:
        ax = ave_dfs[df].plot(grid=True,yticks=yaxis,label=str(df),legend=True)
        nplt=nplt+1
#phase_123_freq_aves.tiff

# %%
#plot average of phase 1 per freq
ave_dfs['phase1full'].plot(grid=True,yticks=yaxis,legend=False)

# %%
#plot average of phase 2 per freq
ave_dfs['phase2full'].plot(grid=True,yticks=yaxis,legend=False)

# %%
#plot average of phase 3 per freq
ave_dfs['phase3full'].plot(grid=True,yticks=yaxis,legend=False)

# %% [markdown]
# ------------

# %% [markdown]
# ----

# %%
#for Kelley

phase1_1252_1256 = pd.Series(ave_dfs['phase1full'][int((308/0.015625)):int((312/0.015625))])
phase2_1252_1256 = pd.Series(ave_dfs['phase2full'][int((304.4/0.015625)):int((308.4/0.015625))])

phase1_1216_1220 = pd.Series(ave_dfs['phase1full'][int((272/0.015625)):int((276/0.015625))])
phase2_1216_1220 = pd.Series(ave_dfs['phase2full'][int((268.4/0.015625)):int((272.4/0.015625))])

phase1_1252_1284 = pd.Series(ave_dfs['phase1full'][int((308/0.015625)):int((340/0.015625))])
phase2_1252_1284 = pd.Series(ave_dfs['phase2full'][int((304.4/0.015625)):int((336.4/0.015625))])

# %%
ax = phase1_1252_1256.plot(grid=True,yticks=yaxis,label='Phase1',legend=True)
phase2_1252_1256.plot(ax=ax,grid=True,yticks=yaxis,label='Phase2',legend=True)

# %%
ax = phase1_1216_1220.plot(grid=True,yticks=yaxis,label='Phase1',legend=True)
phase2_1216_1220.plot(ax=ax,grid=True,yticks=yaxis,label='Phase2',legend=True)

# %%
ax = phase1_1252_1284.plot(grid=True,yticks=yaxis,label='Phase1',legend=True)
phase2_1252_1284.plot(ax=ax,grid=True,yticks=yaxis,label='Phase2',legend=True)
